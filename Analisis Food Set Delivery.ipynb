# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('food_delivery_datasets.csv')
df
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 0     FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1     FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2     FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3     FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4     FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ...          ...             ...                         ...          ...
# 1071  FOOD-10921               0  2018-09-20T15:01:52.152828          900
# 1072  FOOD-10265            5000  2018-07-26T14:43:23.655294         1579
# 1073  FOOD-10534               0  2018-08-21T20:10:59.283185         2606
# 1074  FOOD-10158               0  2018-07-16T14:42:23.214427         2428
# 1075  FOOD-10770               0  2018-09-11T14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
df[['cust_id','delivery_fee']]
# Out:
#       cust_id  delivery_fee
# 0     1089034          4000
# 1      180146         11000
# 2      366528          9000
# 3      511038         14000
# 4     1220358          4000
# ...       ...           ...
# 1071  1296335          4000
# 1072  1135466          7000
# 1073  1383625         15000
# 1074  1094787          9000
# 1075  1010922          9000
#
# [1076 rows x 2 columns]

# %%
1. Ongkir

# %%
#Ongkos kirim paling mahal yang harus dibayar customer
df['delivery_fee'].max()
# Out:
# 44000

# %%
#Ongkos kirim paling murah yang harus dibayar customer
df['delivery_fee'].min()
# Out:
# 0

# %%
#Rata-rata ongkos kirim yang harus dibayar customer
df['delivery_fee'].mean()
# Out:
# 9252.788104089219

# %%
2. Harga Menu

# %%
#Harga menu makanan yang paling mahal
df['food_price'].max()
# Out:
# 448500

# %%
#Harga menu makanan yang paling murah
df['food_price'].min()
# Out:
# 12900

# %%
#Rata-rata harga menu makanan
df['food_price'].mean()
# Out:
# 78041.82156133829

# %%
df[['food_price']].describe()
# Out:
#           food_price
# count    1076.000000
# mean    78041.821561
# std     58512.508208
# min     12900.000000
# 25%     38200.000000
# 50%     59200.000000
# 75%    101100.000000
# max    448500.000000

# %%
3. restoran yang paling diminati

# %%
#Restoran yang paling sering mendapatkan pesanan
df[['resto_id']].value_counts()
# Out:
# resto_id
# 742591683    12
# 742610474    12
# 742731698     9
# 742622470     9
# 742676756     9
#              ..
# 742565366     1
# 742564676     1
# 742564675     1
# 742562594     1
# 742814735     1
# Length: 671, dtype: int64

# %%
4. Rating Restoran

# %%
#banyaknya Restoran dengan rating diatas 4
rating_max=df['rating']>=4
df['rating'][rating_max].count()
# Out:
# 592

# %%
5. Status pemesanan

# %%
#Banyaknya pesanan yang lengkap dan dibatalkan oleh customer
df['status'].value_counts()
# Out:
# Completed    881
# Cancelled    195
# Name: status, dtype: int64

# %%
6. Estimasi waktu pengiriman

# %%
#Estimasi waktu pengiriman pesanan dalam satuan detik (s)
df[['eta_seconds']].describe()
# Out:
#        eta_seconds
# count  1076.000000
# mean   1632.289033
# std     948.628732
# min       2.000000
# 25%    1074.750000
# 50%    1605.500000
# 75%    2151.000000
# max    6082.000000

# %%
#7. Seringnya penggunaan voucher
voucher=df['voucher_amount']>0
df['voucher_amount'][voucher].count()
# Out:
# 162

# %%
voucher=df['voucher_amount']>0
df['voucher_amount'][voucher].value_counts()
# Out:
# 5000     81
# 15000    18
# 4000     15
# 3000     14
# 10000    10
# 2000      6
# 6000      4
# 20000     3
# 25000     3
# 9000      2
# 8000      2
# 16500     2
# 7000      1
# 12000     1
# Name: voucher_amount, dtype: int64

# %%
df[['voucher_amount']].describe()
# Out:
#        voucher_amount
# count     1076.000000
# mean      1053.903346
# std       3127.726510
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      25000.000000

# %%
df=pd.read_csv('food_delivery_datasets.csv')
df.head(15)
# Out:
#       order_id  voucher_amount                   date_time  eta_seconds  \
# 0   FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1   FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2   FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3   FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4   FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# 5   FOOD-10004               0  2018-07-01T14:24:06.719768         2344
# 6   FOOD-10953               0  2018-09-22T13:37:33.712943         1449
# 7   FOOD-10464               0  2018-08-13T20:37:56.355441         2041
# 8   FOOD-10342           10000  2018-08-03T13:58:54.286742         1265
# 9   FOOD-10942               0  2018-09-21T22:51:22.145050         1580
# 10  FOOD-10386               0  2018-08-06T14:57:55.985171         2673
# 11  FOOD-10909            5000  2018-09-19T13:35:35.612145         2149
# ...
